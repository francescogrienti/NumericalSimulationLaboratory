# %% [markdown]
# **EXERCISE_7_02**

# %%
import matplotlib.pyplot as plt
import numpy as np 
import math

# %%
#Acceptance

# %%
solid_acc = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/acceptance.dat")
liquid_acc = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/acceptance.dat")
gas_acc = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/acceptance.dat")

# %%
print(solid_acc[:].mean())
print(liquid_acc[:].mean())
print(gas_acc[:].mean())
# Out:
# 0.508602890914
# 0.5012018532420002
# 0.5775513144500001

# %%
# read the csv data
instant_p_energy_solid = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/instant_penergy.dat")
instant_p_energy_liquid = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/instant_penergy.dat")
instant_p_energy_gas = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/instant_penergy.dat")

# %%
#AUTOCORRELATION FUNCTION 
N = 100000
tmax = N
taumax = 200
plt.figure(figsize=(8,6))
chi = []
for tau in range(taumax):
    s1=0
    s2=0
    s3=0
    s4=0
    s5=0
    # autocorrelation: see lect.6, p.31
    for tp in range(tmax-tau):
        s1 += instant_p_energy_solid[tp]*instant_p_energy_solid[tp+tau]
        s2 += instant_p_energy_solid[tp]
        s3 += instant_p_energy_solid[tp+tau]

    for tp in range(tmax):
        s4 += instant_p_energy_solid[tp]*instant_p_energy_solid[tp]
        s5 += instant_p_energy_solid[tp]

    fatt = 1/(tmax-tau)
    fatt2 = 1/tmax

    num = fatt*s1-fatt*s2*fatt*s3
    den = fatt2*s4 - (fatt2*s5)*(fatt2*s5)

    chi.append(num/den)

plt.plot(chi, color = 'red', label = "solid")
plt.xlabel("Monte carlo time (~ distance between different measurements)")
plt.ylabel("Autocorrelation")
plt.legend()
plt.grid()
plt.title("Autocorrelation vs time distance", fontsize = 18, fontweight = "bold")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#AUTOCORRELATION FUNCTION 
N = 100000
tmax = N
taumax = 200
plt.figure(figsize=(8,6))
chi = []
for tau in range(taumax):
    s1=0
    s2=0
    s3=0
    s4=0
    s5=0
    # autocorrelation: see lect.6, p.31
    for tp in range(tmax-tau):
        s1 += instant_p_energy_liquid[tp]*instant_p_energy_liquid[tp+tau]
        s2 += instant_p_energy_liquid[tp]
        s3 += instant_p_energy_liquid[tp+tau]

    for tp in range(tmax):
        s4 += instant_p_energy_liquid[tp]*instant_p_energy_liquid[tp]
        s5 += instant_p_energy_liquid[tp]

    fatt = 1/(tmax-tau)
    fatt2 = 1/tmax

    num = fatt*s1-fatt*s2*fatt*s3
    den = fatt2*s4 - (fatt2*s5)*(fatt2*s5)

    chi.append(num/den)

plt.plot(chi, color = 'green', label = "liquid")
plt.xlabel("Monte carlo time (~ distance between different measurements)")
plt.ylabel("Autocorrelation")
plt.legend()
plt.grid()
plt.title("Autocorrelation vs time distance", fontsize = 18, fontweight = "bold")
plt.show

# %%
#AUTOCORRELATION FUNCTION 
N = 100000
tmax = N
taumax = 200
plt.figure(figsize=(8,6))
chi = []
for tau in range(taumax):
    s1=0
    s2=0
    s3=0
    s4=0
    s5=0
    # autocorrelation: see lect.6, p.31
    for tp in range(tmax-tau):
        s1 += instant_p_energy_gas[tp]*instant_p_energy_gas[tp+tau]
        s2 += instant_p_energy_gas[tp]
        s3 += instant_p_energy_gas[tp+tau]

    for tp in range(tmax):
        s4 += instant_p_energy_gas[tp]*instant_p_energy_gas[tp]
        s5 += instant_p_energy_gas[tp]

    fatt = 1/(tmax-tau)
    fatt2 = 1/tmax

    num = fatt*s1-fatt*s2*fatt*s3
    den = fatt2*s4 - (fatt2*s5)*(fatt2*s5)

    chi.append(num/den)

plt.plot(chi, color = 'blue', label = "gas")
plt.xlabel("Monte carlo time (~ distance between different measurements)")
plt.ylabel("Autocorrelation")
plt.legend()
plt.grid()
plt.title("Autocorrelation vs time distance", fontsize = 18, fontweight = "bold")
plt.show

# %%
#Analysis of the statistical uncertainties as a function of the block size

#SOLID
def error(AV,AV2,n):  # Function for statistical uncertainty estimation
    if n==0:
        return 0
    else:
        return math.sqrt((AV2[n] - AV[n]**2)/n)

M=len(instant_p_energy_solid) # Total number of throws
N = np.arange(100, 50000, 10)
L = M/N
L = np.array([int(i) for i in L]) 
errors = np.zeros(len(L))

for r in range(len(N)):
    ave = np.zeros(N[r])
    av2 = np.zeros(N[r])
    sum_prog = np.zeros(N[r])
    su2_prog = np.zeros(N[r])
    err_prog = np.zeros(N[r])
    for i in range(N[r]):
        sum1 = 0.
        for j in range(L[r]):
            k = j+i*L[r]
            sum1 += instant_p_energy_solid[k]
        ave[i] = sum1/L[r]     # r_i 
        av2[i] = (ave[i])**2 # (r_i)^2 
    
    for i in range(N[r]):
        for j in range(i+1):
            sum_prog[i] += ave[j] # SUM_{j=0,i} r_j
            su2_prog[i] += av2[j] # SUM_{j=0,i} (r_j)^2
        sum_prog[i]/=(i+1) # Cumulative average
        su2_prog[i]/=(i+1) # Cumulative square average
        err_prog[i] = error(sum_prog,su2_prog,i) # Statistical uncertainty

    errors[r] = err_prog[i].mean()

# %%
print(errors)

# %%
#Analysis of the statistical uncertainties as a function of the block size

#LIQUID
def error(AV,AV2,n):  # Function for statistical uncertainty estimation
    if n==0:
        return 0
    else:
        return math.sqrt((AV2[n] - AV[n]**2)/n)

M=len(instant_p_energy_solid) # Total number of throws
N = np.arange(100, 50000, 10)
L = M/N
L = np.array([int(i) for i in L]) 
errors = np.zeros(len(L))

for r in range(len(N)):
    ave = np.zeros(N[r])
    av2 = np.zeros(N[r])
    sum_prog = np.zeros(N[r])
    su2_prog = np.zeros(N[r])
    err_prog = np.zeros(N[r])
    for i in range(N[r]):
        sum1 = 0.
        for j in range(L[r]):
            k = j+i*L[r]
            sum1 += instant_p_energy_liquid[k]
        ave[i] = sum1/L[r]     # r_i 
        av2[i] = (ave[i])**2 # (r_i)^2 
    
    for i in range(N[r]):
        for j in range(i+1):
            sum_prog[i] += ave[j] # SUM_{j=0,i} r_j
            su2_prog[i] += av2[j] # SUM_{j=0,i} (r_j)^2
        sum_prog[i]/=(i+1) # Cumulative average
        su2_prog[i]/=(i+1) # Cumulative square average
        err_prog[i] = error(sum_prog,su2_prog,i) # Statistical uncertainty

    errors[r] = err_prog[i].mean()

# %%
#TO FIX, aggiungere più valori per L perché così sono troppo pochi 

#Analysis of the statistical uncertainties as a function of the block size

#GAS
def error(AV,AV2,n):  # Function for statistical uncertainty estimation
    if n==0:
        return 0
    else:
        return math.sqrt((AV2[n] - AV[n]**2)/n)

M=len(instant_p_energy_solid) # Total number of throws
N = np.arange(100, 50000, 10)
L = M/N
L = np.array([int(i) for i in L]) 
errors = np.zeros(len(L))
for r in range(len(N)):
    ave = np.zeros(N[r])
    av2 = np.zeros(N[r])
    sum_prog = np.zeros(N[r])
    su2_prog = np.zeros(N[r])
    err_prog = np.zeros(N[r])
    for i in range(N[r]):
        sum1 = 0.
        for j in range(L[r]):
            k = j+i*L[r]
            sum1 += instant_p_energy_gas[k]
        ave[i] = sum1/L[r]     # r_i 
        av2[i] = (ave[i])**2 # (r_i)^2 
    
    for i in range(N[r]):
        for j in range(i+1):
            sum_prog[i] += ave[j] # SUM_{j=0,i} r_j
            su2_prog[i] += av2[j] # SUM_{j=0,i} (r_j)^2
        sum_prog[i]/=(i+1) # Cumulative average
        su2_prog[i]/=(i+1) # Cumulative square average
        err_prog[i] = error(sum_prog,su2_prog,i) # Statistical uncertainty

    errors[r] = err_prog[i].mean()
