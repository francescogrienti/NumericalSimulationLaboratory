# %%
import matplotlib.pyplot as plt
import numpy as np 
import math

# %%
solid_gofr = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/gofr_ave.dat")
liquid_gofr = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/gofr_ave.dat")
gas_gofr = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/gofr_ave.dat")

# %%
solid_pressure = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/pressure.dat")
liquid_pressure = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/pressure.dat")
gas_pressure = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/pressure.dat")

# %%
solid_penergy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/potential_energy.dat")
liquid_penergy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/potential_energy.dat")
gas_penergy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_07/exercise_7_04/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/potential_energy.dat")

# %%
print(solid_pressure[:,2])
# Out:
# [-554.673 -554.659 -554.655 -554.657 -554.655 -554.653 -554.653 -554.654
#  -554.656 -554.656 -554.657 -554.655 -554.655 -554.655 -554.655 -554.653
#  -554.654 -554.654 -554.654 -554.654]

# %%
x = gas_gofr[:,0]
y = gas_gofr[:,1]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=gas_gofr[:,2])
plt.title("Gas-GOFR")
plt.grid(True)
plt.show()

# %%
x = solid_gofr[:,0]
y = solid_gofr[:,1]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=solid_gofr[:,2], color="red")
plt.title("Solid-GOFR")
plt.grid(True)
plt.show()

# %%
x = liquid_gofr[:,0]
y = liquid_gofr[:,1]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=liquid_gofr[:,2], color="green")
plt.title("Liquid-GOFR")
plt.grid(True)
plt.show()

# %% [markdown]
# **PRESSURE**

# %%
M = 40000 #Number of throws
N = 20 #Number of blocks
L = (int)(M/N) #Number of throws per block
x = np.arange(N) 
x *= L

# %%
y = solid_pressure[:,2]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=solid_pressure[:,3], color="green")
plt.title("Solid-Pressure")
plt.grid(True)
plt.show()

# %%
y = liquid_pressure[:,2]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=liquid_pressure[:,3], color="red")
plt.title("Liquid-Pressure")
plt.grid(True)
plt.show()

# %%
y = gas_pressure[:,2]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=gas_pressure[:,3], color="blue")
plt.title("Gas-Pressure")
plt.grid(True)
plt.show()

# %% [markdown]
# **POTENTIAL ENERGY**

# %%
y = solid_penergy[:,2]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=solid_penergy[:,3], color="green")
plt.title("Solid-Potential energy")
plt.grid(True)
plt.show()

# %%
y = liquid_penergy[:,2]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=liquid_penergy[:,3], color="red")
plt.title("Liquid-Potential energy")
plt.grid(True)
plt.show()

# %%
y = gas_penergy[:,2]
plt.figure(figsize=(12,6))
plt.errorbar(x,y,yerr=gas_penergy[:,3], color="blue")
plt.title("Gas-Potential energy")
plt.grid(True)
plt.show()
