# %% [markdown]
# **EXERCISE_04_2**

# %%
import matplotlib
import matplotlib.pyplot as plt#
import numpy as np
import math
import scipy
import os

# %%
#CONTROLLARE SE NECESSARIO FARE CONVERSIONE DI UNITA' DI MISURA

# %% [markdown]
# **SOLID PHASE**

# %%
M = 100000 #Number of throws
N = 200 #Number of blocks
L = (int)(M/N)#Number of throws per block
x = np.arange(N) 
x *= L

# %%
kinetic_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/kinetic_energy.dat")
potential_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/potential_energy.dat")
pressure = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/pressure.dat")
temperature = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/temperature.dat")
total_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_SOLID/total_energy.dat")

# %%
fig = plt.figure(figsize=(12,8))

ax_1 = fig.add_subplot(3, 2, 1)
ax_1.errorbar(x,kinetic_energy[:,2],yerr=kinetic_energy[:,3])
ax_1.set_xlabel('$N_{steps}$')
ax_1.set_ylabel('Kinetic energy')
ax_1.grid(True)
ax_1.set_title("KINETIC ENERGY")

 
ax_2 = fig.add_subplot(3, 2, 2)
ax_2.errorbar(x,potential_energy[:,2],yerr=potential_energy[:,3])
ax_2.set_xlabel('$N_{steps}$')
ax_2.set_ylabel('Potential energy')
ax_2.grid(True)
ax_2.set_title("POTENTIAL ENERGY")

ax_3 = fig.add_subplot(3, 2, 3)
ax_3.errorbar(x,pressure[:,2],yerr=pressure[:,3])
ax_3.set_xlabel('$N_{steps}$')
ax_3.set_ylabel('Pressure')
ax_3.grid(True)
ax_3.set_title("PRESSURE")

ax_4 = fig.add_subplot(3, 2, 4)
ax_4.errorbar(x,temperature[:,2],yerr=temperature[:,3])
ax_4.set_xlabel('$N_{steps}$')
ax_4.set_ylabel('Temperature')
ax_4.grid(True)
ax_4.set_title("TEMPERATURE")

ax_5 = fig.add_subplot(3, 2, 5)
ax_5.errorbar(x,total_energy[:,2],yerr=total_energy[:,3])
ax_5.set_xlabel('$N_{steps}$')
ax_5.set_ylabel('Total energy')
ax_5.grid(True)
ax_5.set_title("TOTAL ENERGY")
# Out:
# Text(0.5, 1.0, 'TOTAL ENERGY')

# %% [markdown]
# **LIQUID PHASE**

# %%
kinetic_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/kinetic_energy.dat")
potential_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/potential_energy.dat")
pressure = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/pressure.dat")
temperature = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/temperature.dat")
total_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_LIQUID/total_energy.dat")

# %%
fig = plt.figure(figsize=(12,8))

ax_1 = fig.add_subplot(3, 2, 1)
ax_1.errorbar(x,kinetic_energy[:,2],yerr=kinetic_energy[:,3])
ax_1.set_xlabel('$N_{steps}$')
ax_1.set_ylabel('Kinetic energy')
ax_1.grid(True)
ax_1.set_title("KINETIC ENERGY")

 
ax_2 = fig.add_subplot(3, 2, 2)
ax_2.errorbar(x,potential_energy[:,2],yerr=potential_energy[:,3])
ax_2.set_xlabel('$N_{steps}$')
ax_2.set_ylabel('Potential energy')
ax_2.grid(True)
ax_2.set_title("POTENTIAL ENERGY")

ax_3 = fig.add_subplot(3, 2, 3)
ax_3.errorbar(x,pressure[:,2],yerr=pressure[:,3])
ax_3.set_xlabel('$N_{steps}$')
ax_3.set_ylabel('Pressure')
ax_3.grid(True)
ax_3.set_title("PRESSURE")

ax_4 = fig.add_subplot(3, 2, 4)
ax_4.errorbar(x,temperature[:,2],yerr=temperature[:,3])
ax_4.set_xlabel('$N_{steps}$')
ax_4.set_ylabel('Temperature')
ax_4.grid(True)
ax_4.set_title("TEMPERATURE")

ax_5 = fig.add_subplot(3, 2, 5)
ax_5.errorbar(x,total_energy[:,2],yerr=total_energy[:,3])
ax_5.set_xlabel('$N_{steps}$')
ax_5.set_ylabel('Total energy')
ax_5.grid(True)
ax_5.set_title("TOTAL ENERGY")
# Out:
# Text(0.5, 1.0, 'TOTAL ENERGY')

# %% [markdown]
# **GASEOUS PHASE**

# %%
kinetic_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/kinetic_energy.dat")
potential_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/potential_energy.dat")
pressure = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/pressure.dat")
temperature = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/temperature.dat")
total_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_04/exercise_4_02/NSL_SIMULATOR/OUTPUT/OUTPUT_GAS/total_energy.dat")

# %%
fig = plt.figure(figsize=(12,8))


ax_1 = fig.add_subplot(3, 2, 1)
ax_1.errorbar(x,kinetic_energy[:,2],yerr=kinetic_energy[:,3])
ax_1.set_xlabel('$N_{steps}$')
ax_1.set_ylabel('Kinetic energy')
ax_1.grid(True)
ax_1.set_title("KINETIC ENERGY")

 
ax_2 = fig.add_subplot(3, 2, 2)
ax_2.errorbar(x,potential_energy[:,2],yerr=potential_energy[:,3])
ax_2.set_xlabel('$N_{steps}$')
ax_2.set_ylabel('Potential energy')
ax_2.grid(True)
ax_2.set_title("POTENTIAL ENERGY")

ax_3 = fig.add_subplot(3, 2, 3)
ax_3.errorbar(x,pressure[:,2],yerr=pressure[:,3])
ax_3.set_xlabel('$N_{steps}$')
ax_3.set_ylabel('Pressure')
ax_3.grid(True)
ax_3.set_title("PRESSURE")

ax_4 = fig.add_subplot(3, 2, 4)
ax_4.errorbar(x,temperature[:,2],yerr=temperature[:,3])
ax_4.set_xlabel('$N_{steps}$')
ax_4.set_ylabel('Temperature')
ax_4.grid(True)
ax_4.set_title("TEMPERATURE")

ax_5 = fig.add_subplot(3, 2, 5)
ax_5.errorbar(x,total_energy[:,2],yerr=total_energy[:,3])
ax_5.set_xlabel('$N_{steps}$')
ax_5.set_ylabel('Total energy')
ax_5.grid(True)
ax_5.set_title("TOTAL ENERGY")
# Out:
# Text(0.5, 1.0, 'TOTAL ENERGY')
