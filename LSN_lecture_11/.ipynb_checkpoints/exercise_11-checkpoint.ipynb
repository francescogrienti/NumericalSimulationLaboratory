# %% [markdown]
# **EXERCISE_11**

# %% [markdown]
# **AGGIUNGERE I COMMENTI AI GRAFICI**

# %% [markdown]
# **11.1 - LINEAR FIT**

# %%
import numpy as np
import warnings
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import math
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from keras.optimizers import Adam


plt.rcParams.update({'font.size': 16})
plt.rcParams["figure.figsize"]= (10,8)
warnings.filterwarnings("ignore")

# %%
def linear(x):
    return (2*x+1)

# %% [markdown]
# **MODEL 1 -- sigma = 0.4, epochs = 15, N_train = 1000**

# %%
# generate training inputs
np.random.seed(0)
x_training = np.random.uniform(-1, 1, 1000)
x_validation = np.random.uniform(-1, 1, 200)
x_validation.sort()
y_target = linear(x_validation)

sigma = 0.4 # noise standard deviation
y_training = np.random.normal(linear(x_training), sigma) #Generation of the measures
y_validation = np.random.normal(linear(x_validation), sigma)

# plot validation and target dataset
plt.plot(x_validation, y_target, label='target')
plt.scatter(x_validation, y_validation, color='g', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model exploiting TensorFlow and Keras
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.compile(optimizer='sgd', loss='mse', metrics=['mse']) #FIX the optimizer, the loss function and the metrics

# fit the model using training dataset
# over 15 epochs of 32 batch size each
history = model.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=15,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_validation, y_validation))
model.get_weights()
# Out:
# Epoch 1/15
# 32/32 [==============================] - 1s 7ms/step - loss: 0.8748 - mse: 0.8748 - val_loss: 0.5775 - val_mse: 0.5775
# Epoch 2/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4029 - mse: 0.4029 - val_loss: 0.3274 - val_mse: 0.3274
# Epoch 3/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2555 - mse: 0.2555 - val_loss: 0.2393 - val_mse: 0.2393
# Epoch 4/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2012 - mse: 0.2012 - val_loss: 0.2027 - val_mse: 0.2027
# Epoch 5/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1782 - mse: 0.1782 - val_loss: 0.1858 - val_mse: 0.1858
# Epoch 6/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1668 - mse: 0.1668 - val_loss: 0.1762 - val_mse: 0.1762
# Epoch 7/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1602 - mse: 0.1602 - val_loss: 0.1703 - val_mse: 0.1703
# Epoch 8/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1561 - mse: 0.1561 - val_loss: 0.1669 - val_mse: 0.1669
# Epoch 9/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1537 - mse: 0.1537 - val_loss: 0.1649 - val_mse: 0.1649
# Epoch 10/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1522 - mse: 0.1522 - val_loss: 0.1636 - val_mse: 0.1636
# Epoch 11/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1512 - mse: 0.1512 - val_loss: 0.1628 - val_mse: 0.1628
# Epoch 12/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1506 - mse: 0.1506 - val_loss: 0.1622 - val_mse: 0.1622
# Epoch 13/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1502 - mse: 0.1502 - val_loss: 0.1619 - val_mse: 0.1619
# Epoch 14/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1499 - mse: 0.1499 - val_loss: 0.1616 - val_mse: 0.1616
# Epoch 15/15
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1497 - mse: 0.1497 - val_loss: 0.1614 - val_mse: 0.1614
# [array([[1.9830481]], dtype=float32), array([1.0113404], dtype=float32)]

# %%
# evaluate model 
score = model.evaluate(x_validation, y_validation, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1614 - mse: 0.1614
#
# Test loss: 0.1614166647195816
# Test accuracy: 0.1614166647195816

# %%
fig, [ax0, ax1] = plt.subplots(1, 2, figsize=(30 , 12))

ax0.plot(history.history['loss'])
ax0.plot(history.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Loss -- Model 1')

x_predicted = np.random.uniform(-1, 1, 200)
y_predicted = model.predict(x_predicted)
ax1.scatter(x_predicted, y_predicted,color='r', label="validation data")
ax1.plot(x_validation, y_target, label='target')
ax1.legend()
ax1.set_title('Prediction -- Model 1')
ax1.grid(True)
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# **MODEL 2 -- sigma = 0.2, epochs = 30, N_train = 900**

# %%
# generate training inputs
np.random.seed(0)
x_training = np.random.uniform(-1, 1, 900)
x_validation = np.random.uniform(-1, 1, 100)
x_validation.sort()
y_target = linear(x_validation)

sigma = 0.2 # noise standard deviation
y_training = np.random.normal(linear(x_training), sigma) #Generation of the measures
y_validation = np.random.normal(linear(x_validation), sigma)

# plot validation and target dataset
plt.plot(x_validation, y_target, label='target')
plt.scatter(x_validation, y_validation, color='g', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model exploiting TensorFlow and Keras
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.compile(optimizer='sgd', loss='mse', metrics=['mse']) #FIX the optimizer, the loss function and the metrics

# fit the model using training dataset
# over 15 epochs of 32 batch size each
history = model.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_validation, y_validation))
model.get_weights()
# Out:
# Epoch 1/30
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6970 - mse: 0.6970 - val_loss: 0.3852 - val_mse: 0.3852
# Epoch 2/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 0.1611 - val_mse: 0.1611
# Epoch 3/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1147 - mse: 0.1147 - val_loss: 0.0899 - val_mse: 0.0899
# Epoch 4/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0695 - mse: 0.0695 - val_loss: 0.0644 - val_mse: 0.0644
# Epoch 5/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0526 - mse: 0.0526 - val_loss: 0.0542 - val_mse: 0.0542
# Epoch 6/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0455 - mse: 0.0455 - val_loss: 0.0494 - val_mse: 0.0494
# Epoch 7/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0471 - val_mse: 0.0471
# Epoch 8/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0459 - val_mse: 0.0459
# Epoch 9/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0389 - mse: 0.0389 - val_loss: 0.0451 - val_mse: 0.0451
# Epoch 10/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0382 - mse: 0.0382 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 11/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0378 - mse: 0.0378 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 12/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0373 - mse: 0.0373 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 13/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0371 - mse: 0.0371 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 14/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0370 - mse: 0.0370 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 15/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0369 - mse: 0.0369 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 16/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0368 - mse: 0.0368 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 17/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 18/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 19/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 20/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 21/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 22/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0367 - mse: 0.0367 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 23/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 24/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 25/30
# 29/29 [==============================] - 0s 4ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 26/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 27/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 28/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 29/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 30/30
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0436 - val_mse: 0.0436
# [array([[1.9860995]], dtype=float32), array([1.0030988], dtype=float32)]

# %%
# evaluate model 
score = model.evaluate(x_validation, y_validation, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0436 - mse: 0.0436
#
# Test loss: 0.043558064848184586
# Test accuracy: 0.043558064848184586

# %%
fig, [ax0, ax1] = plt.subplots(1, 2, figsize=(30 , 12))

ax0.plot(history.history['loss'])
ax0.plot(history.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Loss -- Model 2')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
ax1.scatter(x_predicted, y_predicted,color='r', label="validation data")
ax1.plot(x_validation, y_target, label='target')
ax1.legend()
ax1.set_title('Prediction -- Model 2')
ax1.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# **MODEL 3 -- sigma = 0.1, epochs = 20, N_train = 400**

# %%
# generate training inputs
np.random.seed(0)
x_training = np.random.uniform(-1, 1, 400)
x_validation = np.random.uniform(-1, 1, 50)
x_validation.sort()
y_target = linear(x_validation)

sigma = 0.1 # noise standard deviation
y_training = np.random.normal(linear(x_training), sigma) #Generation of the measures
y_validation = np.random.normal(linear(x_validation), sigma)

# plot validation and target dataset
plt.plot(x_validation, y_target, label='target')
plt.scatter(x_validation, y_validation, color='g', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model exploiting TensorFlow and Keras
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.compile(optimizer='sgd', loss='mse', metrics=['mse']) #FIX the optimizer, the loss function and the metrics

# fit the model using training dataset
# over 15 epochs of 32 batch size each
history = model.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=20,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_validation, y_validation))
model.get_weights()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 0s 12ms/step - loss: 2.0964 - mse: 2.0964 - val_loss: 1.9135 - val_mse: 1.9135
# Epoch 2/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.5780 - mse: 1.5780 - val_loss: 1.4836 - val_mse: 1.4836
# Epoch 3/20
# 13/13 [==============================] - 0s 4ms/step - loss: 1.2173 - mse: 1.2173 - val_loss: 1.1756 - val_mse: 1.1756
# Epoch 4/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.9594 - mse: 0.9594 - val_loss: 0.9471 - val_mse: 0.9471
# Epoch 5/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7691 - mse: 0.7691 - val_loss: 0.7762 - val_mse: 0.7762
# Epoch 6/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6277 - mse: 0.6277 - val_loss: 0.6384 - val_mse: 0.6384
# Epoch 7/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5144 - mse: 0.5144 - val_loss: 0.5309 - val_mse: 0.5309
# Epoch 8/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4268 - mse: 0.4268 - val_loss: 0.4441 - val_mse: 0.4441
# Epoch 9/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3565 - mse: 0.3565 - val_loss: 0.3722 - val_mse: 0.3722
# Epoch 10/20
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2984 - mse: 0.2984 - val_loss: 0.3124 - val_mse: 0.3124
# Epoch 11/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2506 - mse: 0.2506 - val_loss: 0.2636 - val_mse: 0.2636
# Epoch 12/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2116 - mse: 0.2116 - val_loss: 0.2222 - val_mse: 0.2222
# Epoch 13/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1786 - mse: 0.1786 - val_loss: 0.1874 - val_mse: 0.1874
# Epoch 14/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1511 - mse: 0.1511 - val_loss: 0.1590 - val_mse: 0.1590
# Epoch 15/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1287 - mse: 0.1287 - val_loss: 0.1350 - val_mse: 0.1350
# Epoch 16/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1098 - mse: 0.1098 - val_loss: 0.1148 - val_mse: 0.1148
# Epoch 17/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0939 - mse: 0.0939 - val_loss: 0.0977 - val_mse: 0.0977
# Epoch 18/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0804 - mse: 0.0804 - val_loss: 0.0835 - val_mse: 0.0835
# Epoch 19/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0692 - mse: 0.0692 - val_loss: 0.0714 - val_mse: 0.0714
# Epoch 20/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0612 - val_mse: 0.0612
# [array([[1.6269085]], dtype=float32), array([0.9761649], dtype=float32)]

# %%
# evaluate model 
score = model.evaluate(x_validation, y_validation, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0612 - mse: 0.0612
#
# Test loss: 0.0612175278365612
# Test accuracy: 0.0612175278365612

# %%
fig, [ax0, ax1] = plt.subplots(1, 2, figsize=(30 , 12))

ax0.plot(history.history['loss'])
ax0.plot(history.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Loss -- Model 3')

x_predicted = np.random.uniform(-1, 1, 50)
y_predicted = model.predict(x_predicted)
ax1.scatter(x_predicted, y_predicted,color='r', label="validation data")
ax1.plot(x_validation, y_target, label='target')
ax1.legend()
ax1.set_title('Prediction -- Model 3')
ax1.grid(True)
plt.show()
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %% [markdown]
# **MODEL 4 -- sigma = 0.5, epochs = 50, N_train = 900**

# %%
# generate training inputs
np.random.seed(0)
x_training = np.random.uniform(-1, 1, 900)
x_validation = np.random.uniform(-1, 1, 100)
x_validation.sort()
y_target = linear(x_validation)

sigma = 0.5 # noise standard deviation
y_training = np.random.normal(linear(x_training), sigma) #Generation of the measures
y_validation = np.random.normal(linear(x_validation), sigma)

# plot validation and target dataset
plt.plot(x_validation, y_target, label='target')
plt.scatter(x_validation, y_validation, color='g', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# compose the NN model exploiting TensorFlow and Keras
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))
model.compile(optimizer='sgd', loss='mse', metrics=['mse']) #FIX the optimizer, the loss function and the metrics

# fit the model using training dataset
# over 15 epochs of 32 batch size each
history = model.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_validation, y_validation))
model.get_weights()
# Out:
# Epoch 1/50
# 29/29 [==============================] - 0s 7ms/step - loss: 0.8732 - mse: 0.8732 - val_loss: 0.5990 - val_mse: 0.5990
# Epoch 2/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.4316 - mse: 0.4316 - val_loss: 0.3810 - val_mse: 0.3810
# Epoch 3/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2979 - mse: 0.2979 - val_loss: 0.3115 - val_mse: 0.3115
# Epoch 4/50
# 29/29 [==============================] - 0s 5ms/step - loss: 0.2548 - mse: 0.2548 - val_loss: 0.2846 - val_mse: 0.2846
# Epoch 5/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2381 - mse: 0.2381 - val_loss: 0.2771 - val_mse: 0.2771
# Epoch 6/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2333 - mse: 0.2333 - val_loss: 0.2750 - val_mse: 0.2750
# Epoch 7/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2319 - mse: 0.2319 - val_loss: 0.2732 - val_mse: 0.2732
# Epoch 8/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2305 - mse: 0.2305 - val_loss: 0.2726 - val_mse: 0.2726
# Epoch 9/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2300 - mse: 0.2300 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 10/50
# 29/29 [==============================] - 0s 4ms/step - loss: 0.2295 - mse: 0.2295 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 11/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2293 - mse: 0.2293 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 12/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2292 - mse: 0.2292 - val_loss: 0.2720 - val_mse: 0.2720
# Epoch 13/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2291 - mse: 0.2291 - val_loss: 0.2720 - val_mse: 0.2720
# Epoch 14/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 15/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2291 - mse: 0.2291 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 16/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 17/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 18/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 19/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 20/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 21/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 22/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 23/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 24/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 25/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 26/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 27/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 28/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2723 - val_mse: 0.2723
# Epoch 29/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 30/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2723 - val_mse: 0.2723
# Epoch 31/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 32/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 33/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 34/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 35/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 36/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 37/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 38/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 39/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 40/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 41/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 42/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 43/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 44/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2721 - val_mse: 0.2721
# Epoch 45/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2722 - val_mse: 0.2722
# Epoch 46/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2724 - val_mse: 0.2724
# Epoch 47/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2724 - val_mse: 0.2724
# Epoch 48/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2724 - val_mse: 0.2724
# Epoch 49/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2289 - mse: 0.2289 - val_loss: 0.2724 - val_mse: 0.2724
# Epoch 50/50
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2290 - mse: 0.2290 - val_loss: 0.2723 - val_mse: 0.2723
# [array([[1.9738336]], dtype=float32), array([1.0083766], dtype=float32)]

# %%
# evaluate model 
score = model.evaluate(x_validation, y_validation, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2723 - mse: 0.2723
#
# Test loss: 0.27234360575675964
# Test accuracy: 0.27234360575675964

# %%
fig, [ax0, ax1] = plt.subplots(1, 2, figsize=(30 , 12))

ax0.plot(history.history['loss'])
ax0.plot(history.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Loss -- Model 4')

x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
ax1.scatter(x_predicted, y_predicted,color='r', label="validation data")
ax1.plot(x_validation, y_target, label='target')
ax1.legend()
ax1.set_title('Prediction -- Model 4')
ax1.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# **11.2 - POLINOMIAL FIT**

# %%
def polinomial(x):
    return (4-3*x-2*(x**2)+3*(x**3))

# %%
# generate training inputs
np.random.seed(0)
x_training = np.random.uniform(-1, 1, 3000)
x_validation = np.random.uniform(-1, 1, 100)
x_validation.sort()
y_target = polinomial(x_validation)

sigma = 0.5 # noise standard deviation
y_training = np.random.normal(polinomial(x_training), sigma) 
y_validation = np.random.normal(polinomial(x_validation), sigma)

# plot validation and target dataset
plt.plot(x_validation, y_target, label='target')
plt.scatter(x_validation, y_validation, color='r', label='validation data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Model 1 - RELU Adam
model_1 = tf.keras.Sequential()
model_1.add(Dense(30, input_shape=(1,), activation='relu'))
model_1.add(Dense(10, activation='relu'))
model_1.add(Dense(1, activation='relu'))
model_1.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Model 2 - SELU Adam
model_2 = tf.keras.Sequential()
model_2.add(Dense(30, input_shape=(1,), activation='selu'))
model_2.add(Dense(10, activation='selu'))
model_2.add(Dense(1, activation='selu'))
model_2.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Model 3 - ELU Nadam
model_3 = tf.keras.Sequential()
model_3.add(Dense(30, input_shape=(1,), activation='elu'))
model_3.add(Dense(10, activation='elu'))
model_3.add(Dense(1, activation='elu'))
model_3.compile(optimizer='nadam', loss='mse', metrics=['mse'])

# Model 4 - COMINATION MSE
model_4 = tf.keras.Sequential()
model_4.add(Dense(30, input_shape=(1,), activation='elu'))
model_4.add(Dense(10, activation='selu'))
model_4.add(Dense(1, activation='relu'))
model_4.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Model 5 - COMINATION MAE
model_5 = tf.keras.Sequential()
model_5.add(Dense(30, input_shape=(1,), activation='elu'))
model_5.add(Dense(10, activation='selu'))
model_5.add(Dense(1, activation='relu'))
model_5.compile(optimizer='adam', loss='mae', metrics=['mse'])

# Model 6 -SIGMOID
model_6 = tf.keras.Sequential()
model_6.add(Dense(30, input_shape=(1,), activation='sigmoid'))
model_6.add(Dense(10, activation='sigmoid'))
model_6.add(Dense(1))
model_6.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Model 7 - TANH
model_7 = tf.keras.Sequential()
model_7.add(Dense(30, input_shape=(1,), activation='tanh'))
model_7.add(Dense(10, activation='tanh'))
model_7.add(Dense(1))
model_7.compile(optimizer='adam', loss='mse', metrics=['mse'])

# Model 8 - COMBINATION pleteau and open bunds
model_8 = tf.keras.Sequential()
model_8.add(Dense(500, input_shape=(1,), activation='tanh'))
model_8.add(Dense(30, activation='sigmoid'))
model_8.add(Dense(10, activation='relu'))
model_8.add(Dense(1, activation='selu'))
model_8.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
#MODEL 1
history_1 = model_1.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True, 
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 2
history_2 = model_2.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True,
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 3
history_3 = model_3.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True,
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 4
history_4 = model_4.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True,
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 5
history_5 = model_5.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True,
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 6
history_6 = model_6.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True,
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 7
history_7 = model_7.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True,
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
#MODEL 8
history_8 = model_8.fit(x=x_training, y=y_training, 
          batch_size=32, epochs=30,
          shuffle=True, 
          validation_data=(x_validation, y_validation),
          verbose=0)

# %%
# evaluate Models
score_1 = model_1.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_2 = model_2.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_3 = model_3.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_4 = model_4.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_5 = model_5.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_6 = model_6.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_7 = model_7.evaluate(x_validation, y_validation, batch_size=32, verbose=0)
score_8 = model_8.evaluate(x_validation, y_validation, batch_size=32, verbose=0)

print('Model 1:')
print('\tTest loss:', score_1[0])
print('\tTest accuracy:', score_1[1])

print('Model 2:')
print('\tTest loss:', score_2[0])
print('\tTest accuracy:', score_2[1])

print('Model 3:')
print('\tTest loss:', score_3[0])
print('\tTest accuracy:', score_3[1])

print('Model 4:')
print('\tTest loss:', score_4[0])
print('\tTest accuracy:', score_4[1])

print('Model 5:')
print('\tTest loss:', score_5[0])
print('\tTest accuracy:', score_5[1])

print('Model 6:')
print('\tTest loss:', score_6[0])
print('\tTest accuracy:', score_6[1])

print('Model 7:')
print('\tTest loss:', score_7[0])
print('\tTest accuracy:', score_7[1])

print('Model 8:')
print('\tTest loss:', score_8[0])
print('\tTest accuracy:', score_8[1])
# Out:
# Model 1:
# 	Test loss: 0.27195584774017334
# 	Test accuracy: 0.27195584774017334
# Model 2:
# 	Test loss: 0.27469563484191895
# 	Test accuracy: 0.27469563484191895
# Model 3:
# 	Test loss: 0.26980915665626526
# 	Test accuracy: 0.26980915665626526
# Model 4:
# 	Test loss: 0.2788505256175995
# 	Test accuracy: 0.2788505256175995
# Model 5:
# 	Test loss: 0.40853598713874817
# 	Test accuracy: 0.2726287245750427
# Model 6:
# 	Test loss: 0.39219585061073303
# 	Test accuracy: 0.39219585061073303
# Model 7:
# 	Test loss: 0.2753582000732422
# 	Test accuracy: 0.2753582000732422
# Model 8:
# 	Test loss: 0.26709267497062683
# 	Test accuracy: 0.26709267497062683

# %%
# RELU Actitivation
fig, [ax0, ax1, ax2] = plt.subplots(1, 3, figsize=(30 , 12))

ax0.plot(history_1.history['loss'])
ax0.plot(history_1.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Model 1 = loss')

ax1.plot(history_2.history['loss'])
ax1.plot(history_2.history['val_loss'])
ax1.set_ylabel('model loss')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'test/validation'], loc='best')
ax1.set_title('Model 2 = loss')

ax2.plot(history_3.history['loss'])
ax2.plot(history_3.history['val_loss'])
ax2.set_ylabel('model loss')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'test/validation'], loc='best')
ax2.set_title('Model 3 = loss')

plt.show()

# %%
# Combination RELU, SELU, ELU
fig, [ax0, ax1] = plt.subplots(1, 2, figsize=(30 , 12))

ax0.plot(history_4.history['loss'])
ax0.plot(history_4.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Model 4 = loss')

ax1.plot(history_5.history['loss'])
ax1.plot(history_5.history['val_loss'])
ax1.set_ylabel('model loss')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'test/validation'], loc='best')
ax1.set_title('Model 5 = loss')

plt.show()

# %%
# Activation function with plateau
fig, [ax0, ax1, ax2] = plt.subplots(1, 3, figsize=(30 , 12))

ax0.plot(history_6.history['loss'])
ax0.plot(history_6.history['val_loss'])
ax0.set_ylabel('model loss')
ax0.set_xlabel('epoch')
ax0.legend(['train', 'test/validation'], loc='best')
ax0.set_title('Model 6 = loss')

ax1.plot(history_7.history['loss'])
ax1.plot(history_7.history['val_loss'])
ax1.set_ylabel('model loss')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'test/validation'], loc='best')
ax1.set_title('Model 7 = loss')

ax2.plot(history_8.history['loss'])
ax2.plot(history_8.history['val_loss'])
ax2.set_ylabel('model loss')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'test/validation'], loc='best')
ax2.set_title('Model 8 = loss')

plt.show()

# %%
# Activation with no bounds
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted_1 = model_1.predict(x_predicted)
y_predicted_2 = model_2.predict(x_predicted)
y_predicted_3 = model_3.predict(x_predicted)
plt.scatter(x_predicted, y_predicted_1,color='g', label="Model 1")
plt.scatter(x_predicted, y_predicted_2,color='r', label="Model 2")
plt.scatter(x_predicted, y_predicted_3,color='b', label="Model 3")
plt.plot(x_validation, y_target, label='target')
plt.legend()
plt.title('Predicted data - no bounds activation')
plt.grid(True)
plt.show()
# Out:
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 1ms/step

# %%
# Combination RELU, ELU, SELU Actitivation
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted_4 = model_4.predict(x_predicted)
y_predicted_5 = model_5.predict(x_predicted)
plt.scatter(x_predicted, y_predicted_4,color='r', label="Model 4")
plt.scatter(x_predicted, y_predicted_5,color='g', label="Model 5")
plt.plot(x_validation, y_target, label='target')
plt.legend()
plt.title('Predicted data - Combine no bounds activation')
plt.grid(True)
plt.show()
# Out:
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
# Activation function with plateau
x_predicted = np.random.uniform(-1, 1, 500)
y_predicted_6 = model_6.predict(x_predicted)
y_predicted_7 = model_7.predict(x_predicted)
y_predicted_8 = model_8.predict(x_predicted)
plt.scatter(x_predicted, y_predicted_6,color='r', label="Model 6")
plt.scatter(x_predicted, y_predicted_7,color='g', label="Model 7")
plt.scatter(x_predicted, y_predicted_8,color='b', label="Model 8")
plt.plot(x_validation, y_target, label='target')
plt.legend()
plt.title('Predicted data - plateu activation')
plt.grid(True)
plt.show()
# Out:
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %% [markdown]
# **11.3 - SINUSOID FIT**

# %%
def sin(x,y):
    return np.sin(x**2 + y**2)

# %%
from mpl_toolkits import mplot3d

# generate training inputs
np.random.seed(0)
data_training = np.random.uniform(-1.5, 1.5, size=(10000, 2))
data_validation = np.random.uniform(-1.5, 1.5, size=(1000, 2))
data_validation.sort()
target = sin(data_validation[0], data_validation[1])

sigma = 0.5 # noise standard deviation
f_training = np.random.normal(sin2D(data_training[:,0], data_training[:,1]), sigma)
f_validation = np.random.normal(sin2D(data_validation[:,0], data_validation[:,1]), sigma)

test_points = np.random.uniform(-1.5, 1.5, size=(2, 50))
test_points.sort()
x, y = np.meshgrid(test_points[0], test_points[1])
z_target= sin(x,y)
z_validation = np.random.normal(sin(x, y), sigma)

fig = plt.figure(figsize=(18,13))
ax = plt.axes(projection='3d')
ax.scatter(x, y, z_validation, color='green', linewidth=0.1)
ax.contour3D(x, y, z_target, 30, cmap='plasma')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Training data', fontsize=20)
plt.grid(True)

# %%
# Model
model = tf.keras.Sequential()
model.add(Dense(30, input_shape=(2,), activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='relu'))
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# fit the Model 1 using training dataset
history = model.fit(x=data_training, y=f_training, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(data_validation, f_validation),
          verbose=0)

# %%
score = model.evaluate(data_validation, f_validation, batch_size=32, verbose=1)
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2571 - mse: 0.2571
#
# Test loss: 0.2571362257003784
# Test accuracy: 0.2571362257003784

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('model loss')
plt.xlabel('epoch')
plt.legend(['train', 'test/validation'], loc='best')
plt.title('Model - loss')
# Out:
# Text(0.5, 1.0, 'Model - loss')

# %%
data_predicted = np.random.uniform(-1.5, 1.5,size=(1000,2))
f_predicted = model.predict(data_predicted)

test_points = np.random.uniform(-1.5, 1.5, size=(2, 50))
test_points.sort()
x, y = np.meshgrid(test_points[0], test_points[1])
z_target= sin(x,y)

fig = plt.figure(figsize=(18,13))
ax = plt.axes(projection='3d')
ax.scatter(data_predicted[:,0], data_predicted[:,1], f_predicted, color='green', linewidth=0.1, label='predicted')
ax.contour3D(x, y, z_target, 30, cmap='plasma')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.legend()
ax.set_title('Predicted data', fontsize=20)
plt.grid(True)
# Out:
# 32/32 [==============================] - 0s 2ms/step
