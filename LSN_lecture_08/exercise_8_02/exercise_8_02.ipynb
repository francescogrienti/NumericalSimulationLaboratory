# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data_acceptance = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_08/exercise_8_02/results_x_hamiltonian_GS.dat")
data_energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_08/exercise_8_02/results_energy_GS.dat")
data_energy_min = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_08/exercise_8_02/results_H_vs_SA_steps.dat")

# %%
print(data_acceptance[:,0].mean())
# Out:
# 0.5069236621604302

# %%
#Parameters
M = 1000000 #Number of throws
N = 200 #Number of blocks
L = (int)(M/N)#Number of throws per block
x = np.arange(N) 
x *= L

# %%
plt.figure(figsize=(12,6))
plt.errorbar(x, data_energy[:,0],yerr=data_energy[:,1])
plt.grid(True)
plt.show()

# %%
SA_steps = 350
x = np.arange(0,SA_steps)
print(len(data_energy_min[:,0]))
print(len(x))
# Out:
# 350
# 350

# %%
plt.figure(figsize=(12,6))
plt.errorbar(x, data_energy_min[:,0],yerr=data_energy_min[:,1])
plt.grid(True)
plt.show()
