# %% [markdown]
# **NOTEBOOK 6**

# %% [markdown]
# In Statistical Mechanics the one-dimensional (1D) Ising Model is exactly resoluble. The Hamiltonian for a system of N spins with nearest neighbors interaction is given by (in the following units will be assumed such that $\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$, can be exactly computed and it turns out to be:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# Once the partition function has been computed, the Helmholtz free energy is readly obtained as $A = -k_B T \ln Z$. All the thermodynamic quantities of interest can be deduced from $A$ or, equivalently, from $Z$:
#
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$
#
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$
#
# - The **magnetization** (with $h \not= 0$):
#
# Note that with $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$
#
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$
#
# In this framework, the aim of this exercise is to simulate a 1D Ising model sampling different spin configurations according to the Boltzmann distribution leveraging Monte Carlo techniques. In fact, the probability that the spin system assumes a specific configuration depends on the energy of this configuration $$p(\{s_i\})=\frac{\exp(-\beta E(\{s_i\}))}{Z}$$ and therefore one can sample configurations from this PDF. Also, the system is kept at fixed temperature and therefore it was investigated in the canonical ensemble (NVT).
# In this exercise, the Metropolis Algorithm and the Gibbs Algorithm were chosen for the sampling of the probability distribution.
#
# #### Metropolis Algorithm
# - Consider an initial configuration of the spins ---> $s=\{s_1,s_2,...,s_n\}$;
# - Random choice of one spin and flip it to obtain the configuration ---> $s'=\{s_1,...,-s_i,...,s_n\}$
# - Accept the proposed configuration with probability  $A(s'|s)=\min\bigg[1,\frac{p(\{s_i\}')}{p(\{s_i\})}\bigg]$$=\min\bigg[1,\exp(-\beta\Delta E)\bigg]$. It means that if the system moves towards a lower energy configuration the proposed configuration is accepted, otherwise the configurations with higher energy are rejected.
#
# #### Gibbs Algorithm
#
# - Consider an initial configuration of the spins ---> $s=\{s_1,s_2,...,s_n\}$;
# - Random choice of one spin and and set it to +1 or -1 to obtain the configuration --->$s'=\{s_1,...,+1,...,s_n\}$;
# - Set the spin to +1 with a probability given by $\frac{1}{1+\exp(-\beta \Delta E)}$, otherwise set it to -1.
#
# In this way, the algorithm has no rejected moves.
#
# The numerical results for the physical quantities of interest obtained from the simulations are compared to the analytical results in the notebook (in fact, as mentioned above, the 1D Ising model is exactly solvable). The simulations were run starting from $T = 2.0$ and decreasing the temperature by 0.1 at each step until $T = 0.3$ (a bash script ./execute.sh was designed to run the simulations all at once, for more details check it out) starting from the previous spin configuration. In this way, no equilibration was needed before measuring since at the starting temperature $T = 2.0$ the system is at the equilibrium.
# For what concerns the blocking method technique, $N = 20$ blocks of $L = 10^{5}$ steps each were considered.

# %% [markdown]
# ### Exercise 06.1
#
# Complete the NSL_simulator code to simulate a 1D Ising model with the Gibbs sampling algorithm (the Metropolis algorithm is already implemented) to sample the Boltzmann's weight $p(\{ s_i \}) = \exp(-\beta H)/Z$. Verify the possibility to restart from a previous spin configuration.
#
# The code already computes the internal energy: $U(N,T) = \langle H \rangle$. Add the calculation of $C(N,T)$, $\chi(N,T)$, $M(N,T,h)$ and compute:
# 1. $U(N,T) = \langle H \rangle_{h=0}$
# 2. $C(N,T) = k_B \beta^2 (\langle H^2 \rangle_{h=0}-\langle H \rangle_{h=0}^2)$
# 3. $\chi(N,T) = \beta \langle (\sum_{i=1,N}s_i)^2 \rangle_{h=0}$
# 4. $M(N,T,h=0.02)= \langle \sum_{i=1,N}s_i \rangle_{h=0.02}$
#
# as a function of $T$ in the range $\left[0.5;2.0\right]$ for a system of $N=50$ spins with $J=1$.
#
# As usual, use data blocking and give an estimate of the statistical uncertainties.

# %% [markdown]
# - <span style="color:red">Show pictures of your estimations of $U(N,T)$, $C(N,T)$, $\chi(N,T)$, $M(N,T,h=0.02)$ and their uncertainties</span> obtained with a large number of *MC steps* (e.g. $M\ge 10^5$) compared with the exact curves. In the same picture show your results obtained with <span style="color:blue">both sampling methods, Metropolis and Gibbs</span>.
#
# A Monte Carlo step will consist in trying to flip one time all the spins of the system. Do not forget to equilibrate your simulations and to use blocking average with blocks large enough.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy

#Analytical functions
def U(T,J,N):
    beta = 1/T
    frac = (1+np.tanh(beta*J)**(N-2))/(1+np.tanh(beta*J)**N)
    return -J*np.tanh(beta*J)*frac

def Chi(T,J,N):
    beta = 1/T
    tanhN = np.tanh(beta*J)**N
    return beta*np.exp(2*beta*J)*(1-tanhN)/(1+tanhN)

def Heat(T,J,N):
    beta = 1/T
    th = np.tanh(J/T)
    thN= th**N
    ch = 1/th
    heat=((beta*J)**2)*(((1+thN+(N-1)*(th**2)+(N-1)*(ch**2)*thN)/(1+thN))-N*((th+ch*thN)/(1+thN))**2)
    return heat

def Mag(T,J,N,h):
    b=1./T
    l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
    l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
    Z = l1**N + l2**N
    M = (np.exp(b*J)*np.sinh(b*h)*((l1**(N-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(N-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)
    return(M)

# %% [markdown]
# **SPECIFIC HEAT**

# %%
cv_Metr_x, cv_Metr_y, cv_Metr_var  = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/specific_heat_temp_0.000000.dat", unpack=True, usecols=(0,1,2))
cv_Gib_x, cv_Gib_y, cv_Gib_var  = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_GIBBS/specific_heat_temp_0.000000.dat", unpack=True, usecols=(0,1,2))

#theory
points=100
T = np.linspace(0.2,2.1,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )

#theory
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)

# Creo la figura con due subplot affiancati
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Ising 1D, Heat Capacity')
ax1.errorbar(cv_Metr_x, cv_Metr_y, yerr=cv_Metr_var, label="Metropolis", color="green", fmt='8', markersize=14)
ax1.errorbar(cv_Gib_x, cv_Gib_y, yerr=cv_Gib_var, label="Gibbs", color="purple", fmt='s', markersize=7)
ax1.plot(T, heat, label="Theory") 
ax1.set_xlabel('T')
ax1.set_ylabel('c')
ax1.legend()
ax1.grid(True)

ax2.errorbar(cv_Metr_x,cv_Metr_y - Heat(cv_Metr_x, J, Ns), yerr=cv_Metr_var, fmt='o', capsize=5, capthick=1.5, c='orange', label='Metropolis Sampling')
ax2.errorbar(cv_Gib_x, cv_Gib_y - Heat(cv_Gib_x, J, Ns), yerr=cv_Gib_var, fmt='o', capsize=5, capthick=1.5, c='green', label='Gibbs Sampling')
ax2.axhline(y=0, ls='--')
ax2.set_xlabel('T')
ax2.set_ylabel('$(c - c_{model})$')
ax2.legend()
ax2.grid(True)


# Mostro la figura con i due plot affiancati
plt.show()

# %% [markdown]
# **SUSCEPTIBILITY**

# %%
chi_Metr_x, chi_Metr_y, chi_Metr_var = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/susceptibility_temp_0.000000.dat", unpack=True, usecols=(0,1,2))
chi_Gib_x, chi_Gib_y, chi_Gib_var = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_GIBBS/susceptibility_temp_0.000000.dat", unpack=True, usecols=(0,1,2))

#theory
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)

# Creo la figura con due subplot affiancati
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Ising 1D, Susceptibility')
ax1.errorbar(chi_Metr_x, chi_Metr_y, yerr=chi_Metr_var, label="Metropolis", color="green", fmt='8', markersize=14)
ax1.errorbar(chi_Gib_x, chi_Gib_y, yerr=chi_Gib_var, label="Gibbs", color="purple", fmt='s', markersize=7)
ax1.plot(T, X, label="Theory") 
ax1.set_xlabel('T')
ax1.set_ylabel('$\chi$')
ax1.legend()
ax1.grid(True)

ax2.errorbar(chi_Metr_x,chi_Metr_y - Chi(chi_Metr_x, J, Ns), yerr=chi_Metr_var, fmt='o', capsize=5, capthick=1.5, c='orange', label='Metropolis Sampling')
ax2.errorbar(chi_Gib_x, chi_Gib_y - Chi(chi_Gib_x, J, Ns), yerr=chi_Gib_var, fmt='o', capsize=5, capthick=1.5, c='green', label='Gibbs Sampling')
ax2.axhline(y=0, ls='--')
ax2.set_xlabel('T')
ax2.set_ylabel('$(\chi - \chi_{model})$')
ax2.legend()
ax2.grid(True)


# Mostro la figura con i due plot affiancati
plt.show()

# %% [markdown]
# **INTERNAL ENERGY**

# %%
E_Metr_x, E_Metr_y, E_Metr_var = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/energy_temp_0.000000.dat", unpack=True, usecols=(0,1,2))
E_Gib_x, E_Gib_y, E_Gib_var = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_GIBBS/energy_temp_0.000000.dat", unpack=True, usecols=(0,1,2))


# Creo la figura con due subplot affiancati
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Ising 1D, Internal energy')
ax1.errorbar(E_Metr_x, E_Metr_y, yerr=E_Metr_var, label="Metropolis", color="green", fmt='8', markersize=14)
ax1.errorbar(E_Gib_x, E_Gib_y, yerr=E_Gib_var, label="Gibbs", color="purple", fmt='s', markersize=7)
ax1.plot(T, e, label="Theory") 
ax1.set_xlabel('T')
ax1.set_ylabel('U/N')
ax1.legend()
ax1.grid(True)

ax2.errorbar(E_Metr_x,E_Metr_y - U(E_Metr_x, J, Ns), yerr=E_Metr_var, fmt='o', capsize=5, capthick=1.5, c='orange', label='Metropolis Sampling')
ax2.errorbar(E_Gib_x, E_Gib_y - U(E_Gib_x, J, Ns), yerr=E_Gib_var, fmt='o', capsize=5, capthick=1.5, c='green', label='Gibbs Sampling')
ax2.axhline(y=0, ls='--')
ax2.set_xlabel('T')
ax2.set_ylabel('$(U/N - U/N_{model})$')
ax2.legend()
ax2.grid(True)


# Mostro la figura con i due plot affiancati
plt.show()

# %% [markdown]
# **MAGNETIZATION (h=0.02)**

# %%
magn_Metr_x, magn_Metr_y, magn_Metr_var = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/magnetization_temp_0.020000.dat", unpack=True, usecols=(0,1,2))
magn_Gib_x, magn_Gib_y, magn_Gib_var = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_GIBBS/magnetization_temp_0.020000.dat", unpack=True, usecols=(0,1,2))

#theory
h=0.02 #external field
b = 1./T

l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)

# Creo la figura con due subplot affiancati
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Ising 1D, Magnetization (h=0.02)')
ax1.errorbar(magn_Metr_x, magn_Metr_y, yerr=magn_Metr_var, label="Metropolis", color="green", fmt='8', markersize=14)
ax1.errorbar(magn_Gib_x, magn_Gib_y, yerr=magn_Gib_var, label="Gibbs", color="purple", fmt='s', markersize=7)
ax1.plot(T, M, label="Theory") 
ax1.set_xlabel('T')
ax1.set_ylabel('M/N')
ax1.legend()
ax1.grid(True)

ax2.errorbar(magn_Metr_x,magn_Metr_y - Mag(magn_Metr_x, J, Ns, h), yerr=magn_Metr_var, fmt='o', capsize=5, capthick=1.5, c='orange', label='Metropolis Sampling')
ax2.errorbar(magn_Gib_x, magn_Gib_y - Mag(magn_Gib_x, J, Ns, h), yerr=magn_Gib_var, fmt='o', capsize=5, capthick=1.5, c='green', label='Gibbs Sampling')
ax2.axhline(y=0, ls='--')
ax2.set_xlabel('T')
ax2.set_ylabel('$(M/N - (M/N)_{model})$')
ax2.legend()
ax2.grid(True)


# Mostro la figura con i due plot affiancati
plt.show()

# %% [markdown]
# For all the physical quantities of interest the plots show a good agreement between the results obtained from Monte Carlo simulations and analytical results.
