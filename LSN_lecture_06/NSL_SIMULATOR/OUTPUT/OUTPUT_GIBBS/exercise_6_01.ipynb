# %%
import matplotlib
import matplotlib.pyplot as plt#
import numpy as np
import math
import scipy
import os

# %%
cv = np.loadtxt("specific_heat_temp.dat")
chi = np.loadtxt("susceptibility_temp.dat")
energy = np.loadtxt("energy_temp.dat")
magnetization = np.loadtxt("magnetization_temp.dat")

# %%
plt.figure(figsize=(12,6))
plt.scatter(cv[:,0], cv[:,1])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(chi[:,0], chi[:,1])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(energy[:,0], energy[:,1])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(magnetization[:,0], magnetization[:,1])
plt.grid(True)
plt.show()
