# %%
import matplotlib
import matplotlib.pyplot as plt#
import numpy as np
import math
import scipy
import os

# %%
print(os.getcwd())

# %%
cv = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/specific_heat_temp.dat")
chi = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/susceptibility_temp.dat")
energy = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/energy_temp.dat")
magnetization = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/OUTPUT_METROPOLIS/magnetization_temp.dat")

# %%
plt.figure(figsize=(12,6))
plt.scatter(cv[:,0], cv[:,1])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(chi[:,0], chi[:,1])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(energy[:,0], energy[:,1])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.scatter(magnetization[:,0], magnetization[:,1])
plt.grid(True)
plt.show()

# %%
eq_gibbs = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/EQUILIBRATION_GIBBS/total_energy.dat")
eq_metro = np.loadtxt("/home/francesco/NumericalSimulationLaboratory/LSN_lecture_06/NSL_SIMULATOR/OUTPUT/EQUILIBRATION_METROPOLIS/total_energy.dat")

# %%
x = np.arange(0, len(eq_gibbs[:]))
print(x)
# Out:
# [   0    1    2 ... 9997 9998 9999]

# %%
plt.figure(figsize=(12,6))
plt.plot(x, eq_gibbs[:])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(x, eq_metro[:])
plt.grid(True)
plt.show()
